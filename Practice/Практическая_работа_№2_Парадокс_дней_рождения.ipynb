# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxrgrz/University/blob/main/Practice/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%962_%D0%9F%D0%B0%D1%80%D0%B0%D0%B4%D0%BE%D0%BA%D1%81_%D0%B4%D0%BD%D0%B5%D0%B9_%D1%80%D0%BE%D0%B6%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практическая работа №2. Парадокс дней рождения
#
# Парадокс дней рождения - это интересное явление в теории вероятностей, которое часто удивляет людей своим неожиданным результатом.
#
# **Суть парадокса:**
# - В группе из 23 или более человек вероятность того, что у хотя бы двух людей совпадут дни рождения, превышает 50%.
# - При увеличении группы до 60 человек эта вероятность возрастает до более чем 99%.

# %% [markdown]
# **Почему это кажется парадоксальным:**
# Многие люди интуитивно полагают, что для такой высокой вероятности совпадения нужно гораздо больше людей. Это связано с тем, что мы часто неправильно оцениваем количество возможных пар в группе.
#
# **Объяснение:**
# - В группе из 23 человек можно составить 253 уникальные пары.
# - Каждая пара имеет шанс на совпадение дней рождения.
# - Большое количество возможных пар значительно увеличивает вероятность хотя бы одного совпадения.

# %% [markdown]
# #### **Задание**

# %% [markdown]
# - Напишите программу, которая симулирует парадокс дней рождения и проверяет его достоверность.
#
# - **Упрощение:** Для удобства расчетов считайте, что в каждом месяце 28 дней (всего 336 возможных дней рождения в году).
#
# - **Требования к программе:**
#
#   1. Создайте функцию `birthday(iterations, people=23)`, которая:
#     - Принимает параметр `iterations` - количество повторений эксперимента.
#     - Принимает параметр `people` - количество человек в группе (по умолчанию 23).
#     - Проводит указанное количество симуляций для группы из `people` человек.
#     - Возвращает **процент случаев**, когда было обнаружено совпадение дней рождения, в виде числа с плавающей точкой.
#
#   2. Алгоритм работы функции:
#     - Генерируйте случайные дни рождения для заданного количества людей.
#     - Проверяйте, есть ли совпадения дней рождения в этой группе.
#     - Повторите этот процесс указанное количество раз (`iterations`).
#     - Подсчитайте процент случаев, когда были обнаружены совпадения.
#
#   3. В основной части программы:
#     - Используйте функцию `birthday()` для проверки вероятности совпадений для групп разного размера (например, от 10 до 60 человек).
#     - Выведите результаты, показывающие, как изменяется вероятность совпадения с увеличением размера группы.
#
# **Пример использования:**
#
# ```python
# result_23 = birthday(10000, 23)
# print(f"Вероятность совпадения дней рождения в группе из 23 человек: {result_23:.2f}%")
#
# result_60 = birthday(10000, 60)
# print(f"Вероятность совпадения дней рождения в группе из 60 человек: {result_60:.2f}%")
# ```

# %%
import random
def birthday(cicl, human=23):
    k = 0
    for i in range(cicl):
        birthdays = [random.randint(1, 336) for g in range(human)]
        if len(birthdays) != len(set(birthdays)):
            k += 1
    dr = (k / cicl) * 100
    return dr
for u in range(10, 61):
    result = birthday(10000,u)
    print(f"Вероятность совпадения дней рождения в группе из {u} человек: {result:.2f}%")
# Out:
# Вероятность совпадения дней рождения в группе из 10 человек: 12.37%
# Вероятность совпадения дней рождения в группе из 11 человек: 14.84%
# Вероятность совпадения дней рождения в группе из 12 человек: 17.76%
# Вероятность совпадения дней рождения в группе из 13 человек: 21.15%
# Вероятность совпадения дней рождения в группе из 14 человек: 23.73%
# Вероятность совпадения дней рождения в группе из 15 человек: 27.48%
# Вероятность совпадения дней рождения в группе из 16 человек: 30.77%
# Вероятность совпадения дней рождения в группе из 17 человек: 33.55%
# Вероятность совпадения дней рождения в группе из 18 человек: 37.01%
# Вероятность совпадения дней рождения в группе из 19 человек: 39.39%
# Вероятность совпадения дней рождения в группе из 20 человек: 44.15%
# Вероятность совпадения дней рождения в группе из 21 человек: 46.42%
# Вероятность совпадения дней рождения в группе из 22 человек: 50.69%
# Вероятность совпадения дней рождения в группе из 23 человек: 54.07%
# Вероятность совпадения дней рождения в группе из 24 человек: 56.84%
# Вероятность совпадения дней рождения в группе из 25 человек: 59.85%
# Вероятность совпадения дней рождения в группе из 26 человек: 62.84%
# Вероятность совпадения дней рождения в группе из 27 человек: 65.70%
# Вероятность совпадения дней рождения в группе из 28 человек: 67.81%
# Вероятность совпадения дней рождения в группе из 29 человек: 70.41%
# Вероятность совпадения дней рождения в группе из 30 человек: 74.21%
# Вероятность совпадения дней рождения в группе из 31 человек: 76.13%
# Вероятность совпадения дней рождения в группе из 32 человек: 78.75%
# Вероятность совпадения дней рождения в группе из 33 человек: 79.94%
# Вероятность совпадения дней рождения в группе из 34 человек: 82.39%
# Вероятность совпадения дней рождения в группе из 35 человек: 83.92%
# Вероятность совпадения дней рождения в группе из 36 человек: 85.61%
# Вероятность совпадения дней рождения в группе из 37 человек: 86.80%
# Вероятность совпадения дней рождения в группе из 38 человек: 88.92%
# Вероятность совпадения дней рождения в группе из 39 человек: 89.67%
# Вероятность совпадения дней рождения в группе из 40 человек: 91.66%
# Вероятность совпадения дней рождения в группе из 41 человек: 92.82%
# Вероятность совпадения дней рождения в группе из 42 человек: 93.42%
# Вероятность совпадения дней рождения в группе из 43 человек: 93.75%
# Вероятность совпадения дней рождения в группе из 44 человек: 94.54%
# Вероятность совпадения дней рождения в группе из 45 человек: 95.27%
# Вероятность совпадения дней рождения в группе из 46 человек: 96.28%
# Вероятность совпадения дней рождения в группе из 47 человек: 96.59%
# Вероятность совпадения дней рождения в группе из 48 человек: 97.13%
# Вероятность совпадения дней рождения в группе из 49 человек: 97.25%
# Вероятность совпадения дней рождения в группе из 50 человек: 98.01%
# Вероятность совпадения дней рождения в группе из 51 человек: 98.23%
# Вероятность совпадения дней рождения в группе из 52 человек: 98.67%
# Вероятность совпадения дней рождения в группе из 53 человек: 98.49%
# Вероятность совпадения дней рождения в группе из 54 человек: 98.92%
# Вероятность совпадения дней рождения в группе из 55 человек: 99.02%
# Вероятность совпадения дней рождения в группе из 56 человек: 99.26%
# Вероятность совпадения дней рождения в группе из 57 человек: 99.25%
# Вероятность совпадения дней рождения в группе из 58 человек: 99.48%
# Вероятность совпадения дней рождения в группе из 59 человек: 99.65%
# Вероятность совпадения дней рождения в группе из 60 человек: 99.66%
