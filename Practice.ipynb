# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxrgrz/University/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d = {}
print("Выберите действие:")
print('1. Добавить контакт\n2. Удалить контакт\n3. Показать список контактов\n4. Изменить номер контакта\n5. Выход')
print("Выберите номер функционала:")
i = int(input())
f = True
while f == True:
    if i == 1:
        k = []
        print("Введите имя:")
        s = input()
        p = ''
        print("Введите номер в формате (9xxxxxxxxx):")
        m = input()
        for j in (s.split()):
            k.append(j[0].upper() + j[1:len(s)].lower())
        p = k[0]
        for l in range(1, len(k)):
            p += ' ' + k[l]
        if m.isdigit() and m[0] == '9' and len(m) == 10:
            d[p] = '+7' + str(m)
            print(f"Контакт {p} успешно добавлен!\n")
        else:
          print("Неправльно набран номер\n")
        print("Выберите следующее действие:")
        print('1. Добавить контакт\n2. Удалить контакт\n3. Показать список контактов\n4. Изменить номер контакта\n5. Выход')
        print("Выберите номер функционала:")
        i = int(input())
    if i == 2:
        k = []
        print("Введите имя:")
        s = input()
        p = ''
        for j in (s.split()):
            k.append(j[0].upper() + j[1:len(s)].lower())
        p = k[0]
        for l in range(1, len(k)):
            p += ' ' + k[l]
        if p in d.keys():
            d.pop(p)
            print(f"Контакт {p} успешно удален!\n")
        else:
            print("контакт не найден\n")
        print("Выберите следующее действие:")
        print('1. Добавить контакт\n2. Удалить контакт\n3. Показать список контактов\n4. Изменить номер контакта\n5. Выход')
        print("Выберите номер функционала:")
        i = int(input())
    if i == 3:
        m = list(d.keys())

        if len(m)>0:
            for num in m:
                print(num, d[num])

        else:
            print('нет контактов\n')

        print('выберите следующее действие:')
        i = int(input())
    if i == 4:
        k = []
        print('Введите имя:')
        s = input()
        p = ''
        for j in (s.split()):
            k.append(j[0].upper() + j[1:len(s)].lower())
        p = k[0]
        for l in range(1, len(k)):
            p += ' ' + k[l]
        print("Введите новый номер:")
        m = input()
        if m.isdigit() and m[0] == '9' and len(m) == 10:
            d[p] = '+7' + str(m)
            print(f'контакт {p} успешко заменен!\n')
        else:
          print("введите номер в формате (9ххххххххх):")
        print("Выберите следующее действие:")
        print('1. Добавить контакт\n2. Удалить контакт\n3. Показать список контактов\n4. Изменить номер контакта\n5. Выход')
        print("Выберите номер функционала:")
        i = int(input())
    if i == 5:
        print("Программа завершена.")
        f = False
# Out:
# Выберите действие:
# 1. Добавить контакт
# 2. Удалить контакт
# 3. Показать список контактов
# 4. Изменить номер контакта
# 5. Выход
# Выберите номер функционала:
# 1
# Введите имя:
# семен
# Введите номер в формате (9xxxxxxxxx):
# 9431925678
# Контакт Семен успешно добавлен!
#
# Выберите следующее действие:
# 1. Добавить контакт
# 2. Удалить контакт
# 3. Показать список контактов
# 4. Изменить номер контакта
# 5. Выход
# Выберите номер функционала:
# 1
# Введите имя:
# Нимгир
# Введите номер в формате (9xxxxxxxxx):
# 9107564949
# Контакт Нимгир успешно добавлен!
#
# Выберите следующее действие:
# 1. Добавить контакт
# 2. Удалить контакт
# 3. Показать список контактов
# 4. Изменить номер контакта
# 5. Выход
# Выберите номер функционала:
# 3
# Семен +79431925678
# Нимгир +79107564949
# выберите следующее действие:
# 2
# Введите имя:
# Семен
# Контакт Семен успешно удален!
#
# Выберите следующее действие:
# 1. Добавить контакт
# 2. Удалить контакт
# 3. Показать список контактов
# 4. Изменить номер контакта
# 5. Выход
# Выберите номер функционала:
# 3
# Нимгир +79107564949
# выберите следующее действие:
